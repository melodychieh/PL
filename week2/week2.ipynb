# %%
import pandas as pd
import pandas as pd
df_csv = pd.read_csv("adult.csv")
df_csv
# Out:
#        Age          Workclass  Income    Education  Education-Num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# 1       Married-civ-spouse     Exec-managerial         Husband   White
# 2                 Divorced   Handlers-cleaners   Not-in-family   White
# 3       Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4       Married-civ-spouse      Prof-specialty            Wife   Black
# ...                    ...                 ...             ...     ...
# 32556   Married-civ-spouse        Tech-support            Wife   White
# 32557   Married-civ-spouse   Machine-op-inspct         Husband   White
# 32558              Widowed        Adm-clerical       Unmarried   White
# 32559        Never-married        Adm-clerical       Own-child   White
# 32560   Married-civ-spouse     Exec-managerial            Wife   White
#
#            Sex  Capital Gain  Capital Loss  Hours per Week  Native Country
# 0         Male          2174             0              40   United-States
# 1         Male             0             0              13   United-States
# 2         Male             0             0              40   United-States
# 3         Male             0             0              40   United-States
# 4       Female             0             0              40            Cuba
# ...        ...           ...           ...             ...             ...
# 32556   Female             0             0              38   United-States
# 32557     Male             0             0              40   United-States
# 32558   Female             0             0              40   United-States
# 32559     Male             0             0              20   United-States
# 32560   Female         15024             0              40   United-States
#
# [32561 rows x 14 columns]

# %%
df = pd.read_csv('adult.csv')
# 計算薪資的平均值
mean_salary = np.mean(df['Income'])
print("平均薪資:", mean_salary)
# 計算薪資的標準差
std_salary = np.std(df['Income'])
print("薪資標準差:", std_salary)
# 計算薪資的中位數
median_salary = np.median(df['Income'])
print("薪資中位數:", median_salary)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30840\503600422.py in <module>
#       1 df = pd.read_csv('adult.csv')
#       2 # 計算薪資的平均值
# ----> 3 mean_salary = np.mean(df['Income'])
#       4 print("平均薪資:", mean_salary)
#       5 # 計算薪資的標準差
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
df = pd.read_csv('adult.csv')
# 計算薪資的平均值
mean_salary = np.mean(df['Income'])
print("平均薪資:", mean_salary)
# 計算薪資的標準差
std_salary = np.std(df['Income'])
print("薪資標準差:", std_salary)
# 計算薪資的中位數
median_salary = np.median(df['Income'])
print("薪資中位數:", median_salary)
# Out:
# 平均薪資: 189778.36651208502
# 薪資標準差: 105548.3568808909
# 薪資中位數: 178356.0

# %%
# 使用 Matplotlib 繪製薪資分布的直方圖
plt.hist(df['Income'], bins=10, edgecolor='black')
plt.xlabel('薪資')
plt.ylabel('頻率')
plt.title('薪資分布直方圖')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30840\3848900554.py in <module>
#       1 # 使用 Matplotlib 繪製薪資分布的直方圖
# ----> 2 plt.hist(df['Income'], bins=10, edgecolor='black')
#       3 plt.xlabel('薪資')
#       4 plt.ylabel('頻率')
#       5 plt.title('薪資分布直方圖')
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt

# %%
# 使用 Matplotlib 繪製薪資分布的直方圖
plt.hist(df['Income'], bins=10, edgecolor='black')
plt.xlabel('薪資')
plt.ylabel('頻率')
plt.title('薪資分布直方圖')
plt.show()
# Out:
# D:\program files\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 34218 (\N{CJK UNIFIED IDEOGRAPH-85AA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\program files\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 36039 (\N{CJK UNIFIED IDEOGRAPH-8CC7}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\program files\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 20998 (\N{CJK UNIFIED IDEOGRAPH-5206}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\program files\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 24067 (\N{CJK UNIFIED IDEOGRAPH-5E03}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\program files\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 30452 (\N{CJK UNIFIED IDEOGRAPH-76F4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\program files\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 26041 (\N{CJK UNIFIED IDEOGRAPH-65B9}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\program files\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22294 (\N{CJK UNIFIED IDEOGRAPH-5716}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\program files\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 38971 (\N{CJK UNIFIED IDEOGRAPH-983B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# D:\program files\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 使用 Matplotlib 繪製薪資分布的直方圖
plt.hist(df['Income'], bins=10, edgecolor='black')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.title('Salary Distribution')
plt.show()
